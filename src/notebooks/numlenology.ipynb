# %% [markdown]
# https://stackoverflow.com/questions/39657395/how-to-draw-properly-networkx-graphs

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from numlenology.core import LANGS, build_graph

for lang in LANGS:
    g = build_graph(lang=lang)
    g.render(f"graphs/{lang}", format="png")
    # clean extra files generated by g.render().
    # !rm graphs/{lang}

# %%
from IPython.display import Image
Image("graphs/fr.png")

# %%
# tiebreak: ja vs ko
from unidecode import unidecode
from num2words import num2words

for i in range(21):
    j = unidecode(num2words(i, lang="ja"))
    k = unidecode(num2words(i, lang="ko"))
    print(f"{i}, {j}, {k}")
# Out:
# 0, Ling , yeong
# 1, Yi , il
# 2, Er , i
# 3, San , sam
# 4, Si , sa
# 5, Wu , o
# 6, Liu , yug
# 7, Qi , cil
# 8, Ba , pal
# 9, Jiu , gu
# 10, Shi , sib
# 11, Shi Yi , sibil
# 12, Shi Er , sibi
# 13, Shi San , sibsam
# 14, Shi Si , sibsa
# 15, Shi Wu , sibo
# 16, Shi Liu , sibyug
# 17, Shi Qi , sibcil
# 18, Shi Ba , sibpal
# 19, Shi Jiu , sibgu
# 20, Er Shi , isib
